# %%
from ensemble_from_predictions import run_ensemble
import os; 
from dotenv import load_dotenv
load_dotenv()
inputs = [
    "results/rule_dimension_qa_context_with_predictions.csv", #Run GPT-5-MCERF-Main.py first to generate this file save it in results/
    "results2/rule_dimension_qa_context_with_predictions.csv", #Run GPT-5-MCERF-Main.py first to generate this file save it in results2/
    "results3/rule_dimension_qa_context_with_predictions.csv", #Run GPT-5-MCERF-Main.py first to generate this file save it in results3/
    "results4/rule_dimension_qa_context_with_predictions.csv", #Run GPT-5-MCERF-Main.py first to generate this file save it in results4/
    "results5/rule_dimension_qa_context_with_predictions.csv", #Run GPT-5-MCERF-Main.py first to generate this file save it in results5/
]
output = "results_ensemble/rule_dimension_qa_ENSEMBLED.csv" #create this results_ensemble directory before running the code

os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY", "your-openai-api-key-here")
run_ensemble(inputs, output, model="gpt-5-mini")
